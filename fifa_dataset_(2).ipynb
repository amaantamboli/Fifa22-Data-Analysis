# %% [markdown]
# **This project is made by Vikrant Pote and Amaan Tamboli, Under the guidence of prof. ISha Sehgal Ma'am**

# %% [markdown]
# **This is dataset of UNICORN COMPANIES OF INDIA and we have did the Exploratory Data Analysis (EDA) and Machine Learning (ML) Model**

# %% [markdown]
# # Index
#
# 1.   Data summary of tallent in countires.
# 2.   Data summary of tallent in clubs.
# 3.   Data summary of players per Country.
# 4.   Data summary of top 3 players.
# 5.   Data summary of highest paid player.

# %% [markdown]
# # Importing libraries:-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Reading dataset:-

# %%
df=pd.read_csv("/content/players_fifa22.csv")

# %%
df.head(5)
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2      83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3      73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4      87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0       93         93  ...      93.0      90.0      93.0      69.0      67.0
# 1       92         92  ...      87.0      83.0      87.0      67.0      69.0
# 2       91         91  ...      89.0      81.0      89.0      66.0      62.0
# 3       91         95  ...      92.0      84.0      92.0      70.0      66.0
# 4       91         93  ...      38.0      41.0      38.0      35.0      39.0
#
#   RWBRating  LBRating  CBRating  RBRating GKRating
# 0      69.0      64.0      53.0      64.0     22.0
# 1      67.0      64.0      63.0      64.0     22.0
# 2      66.0      63.0      56.0      63.0     23.0
# 3      70.0      66.0      57.0      66.0     21.0
# 4      35.0      35.0      36.0      35.0     92.0
#
# [5 rows x 90 columns]

# %%
#dataframe shape:-
df.shape
# Out:
# (7924, 90)

# %%
#dataframe information:-
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7924 entries, 0 to 7923
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 7924 non-null   int64
#  1   Name               7924 non-null   object
#  2   FullName           7924 non-null   object
#  3   Age                7924 non-null   int64
#  4   Height             7924 non-null   int64
#  5   Weight             7924 non-null   int64
#  6   PhotoUrl           7924 non-null   object
#  7   Nationality        7924 non-null   object
#  8   Overall            7924 non-null   int64
#  9   Potential          7924 non-null   int64
#  10  Growth             7924 non-null   int64
#  11  TotalStats         7924 non-null   int64
#  12  BaseStats          7924 non-null   int64
#  13  Positions          7924 non-null   object
#  14  BestPosition       7924 non-null   object
#  15  Club               7924 non-null   object
#  16  ValueEUR           7924 non-null   int64
#  17  WageEUR            7924 non-null   int64
#  18  ReleaseClause      7924 non-null   int64
#  19  ClubPosition       7883 non-null   object
#  20  ContractUntil      7883 non-null   float64
#  21  ClubNumber         7883 non-null   float64
#  22  ClubJoined         7924 non-null   int64
#  23  OnLoad             7924 non-null   bool
#  24  NationalTeam       7924 non-null   object
#  25  NationalPosition   683 non-null    object
#  26  NationalNumber     683 non-null    float64
#  27  PreferredFoot      7924 non-null   object
#  28  IntReputation      7924 non-null   int64
#  29  WeakFoot           7924 non-null   int64
#  30  SkillMoves         7924 non-null   int64
#  31  AttackingWorkRate  7924 non-null   object
#  32  DefensiveWorkRate  7924 non-null   object
#  33  PaceTotal          7924 non-null   int64
#  34  ShootingTotal      7924 non-null   int64
#  35  PassingTotal       7924 non-null   int64
#  36  DribblingTotal     7924 non-null   int64
#  37  DefendingTotal     7924 non-null   int64
#  38  PhysicalityTotal   7924 non-null   int64
#  39  Crossing           7924 non-null   int64
#  40  Finishing          7924 non-null   int64
#  41  HeadingAccuracy    7924 non-null   int64
#  42  ShortPassing       7924 non-null   int64
#  43  Volleys            7924 non-null   int64
#  44  Dribbling          7924 non-null   int64
#  45  Curve              7924 non-null   int64
#  46  FKAccuracy         7924 non-null   int64
#  47  LongPassing        7924 non-null   int64
#  48  BallControl        7924 non-null   int64
#  49  Acceleration       7924 non-null   int64
#  50  SprintSpeed        7924 non-null   int64
#  51  Agility            7924 non-null   int64
#  52  Reactions          7924 non-null   int64
#  53  Balance            7924 non-null   int64
#  54  ShotPower          7924 non-null   int64
#  55  Jumping            7924 non-null   int64
#  56  Stamina            7924 non-null   int64
#  57  Strength           7924 non-null   int64
#  58  LongShots          7924 non-null   int64
#  59  Aggression         7924 non-null   int64
#  60  Interceptions      7924 non-null   int64
#  61  Positioning        7924 non-null   int64
#  62  Vision             7924 non-null   int64
#  63  Penalties          7924 non-null   int64
#  64  Composure          7924 non-null   int64
#  65  Marking            7924 non-null   int64
#  66  StandingTackle     7924 non-null   int64
#  67  SlidingTackle      7924 non-null   int64
#  68  GKDiving           7923 non-null   float64
#  69  GKHandling         7923 non-null   float64
#  70  GKKicking          7923 non-null   float64
#  71  GKPositioning      7923 non-null   float64
#  72  GKReflexes         7923 non-null   float64
#  73  STRating           7923 non-null   float64
#  74  LWRating           7923 non-null   float64
#  75  LFRating           7923 non-null   float64
#  76  CFRating           7923 non-null   float64
#  77  RFRating           7923 non-null   float64
#  78  RWRating           7923 non-null   float64
#  79  CAMRating          7923 non-null   float64
#  80  LMRating           7923 non-null   float64
#  81  CMRating           7923 non-null   float64
#  82  RMRating           7923 non-null   float64
#  83  LWBRating          7923 non-null   float64
#  84  CDMRating          7923 non-null   float64
#  85  RWBRating          7923 non-null   float64
#  86  LBRating           7923 non-null   float64
#  87  CBRating           7923 non-null   float64
#  88  RBRating           7923 non-null   float64
#  89  GKRating           7923 non-null   float64
# dtypes: bool(1), float64(25), int64(51), object(13)
# memory usage: 5.4+ MB

# %% [markdown]
# # Handeling null values:-

# %%
#Finding null values:-
df.isnull().sum().sort_values(ascending=False)
# Out:
# NationalNumber       7241
# NationalPosition     7241
# ClubNumber             41
# ContractUntil          41
# ClubPosition           41
#                      ...
# DefensiveWorkRate       0
# AttackingWorkRate       0
# SkillMoves              0
# WeakFoot                0
# Curve                   0
# Length: 90, dtype: int64

# %%
df[['ClubPosition','ContractUntil','ClubNumber']]
# Out:
#      ClubPosition  ContractUntil  ClubNumber
# 0              RW         2023.0        30.0
# 1              ST         2023.0         9.0
# 2              ST         2023.0         7.0
# 3              ST         2022.0         7.0
# 4              GK         2023.0        13.0
# ...           ...            ...         ...
# 7919           RB         2022.0        23.0
# 7920          CDM         2024.0        13.0
# 7921           ST         2023.0        33.0
# 7922          CDM         2021.0        22.0
# 7923          CDM         2022.0         8.0
#
# [7924 rows x 3 columns]

# %%
#dropping null columns:-
df.drop(['NationalPosition','NationalNumber'], axis=1,inplace=True)

# %%
#New shape:-
df.shape
# Out:
# (7924, 88)

# %%
#filling null values:-
df.fillna({
    'ClubPosition' : 'Notknown',
    'ContractUntil': 'Notknown',
    'ClubNumber'   :  0
},inplace=True)

# %% [markdown]
# # Data Visualization:-

# %% [markdown]
# Top tallents in countries:-

# %%
top_players=df[df['Overall']>85]

# %%
top_players
# Out:
#         ID               Name                        FullName  Age  Height  \
# 0   158023           L. Messi                    Lionel Messi   34     170
# 1   188545     R. Lewandowski              Robert Lewandowski   32     185
# 2    20801  Cristiano Ronaldo    C. Ronaldo dos Santos Aveiro   36     187
# 3   231747          K. Mbappé                   Kylian Mbappé   22     182
# 4   200389           J. Oblak                       Jan Oblak   28     188
# ..     ...                ...                             ...  ...     ...
# 64  210514       João Cancelo       João Pedro Cavaco Cancelo   27     182
# 65  212218         A. Laporte                 Aymeric Laporte   27     191
# 66  213345           K. Coman                  Kingsley Coman   25     180
# 67  218667     Bernardo Silva  Bernardo Mota Carvalho e Silva   26     173
# 68  209499            Fabinho          Fábio Henrique Tavares   27     188
#
#     Weight                                          PhotoUrl Nationality  \
# 0       72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1       81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2       83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3       73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4       87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
# ..     ...                                               ...         ...
# 64      74  https://cdn.sofifa.com/players/210/514/22_60.png    Portugal
# 65      85  https://cdn.sofifa.com/players/212/218/22_60.png       Spain
# 66      76  https://cdn.sofifa.com/players/213/345/22_60.png      France
# 67      64  https://cdn.sofifa.com/players/218/667/22_60.png    Portugal
# 68      78  https://cdn.sofifa.com/players/209/499/22_60.png      Brazil
#
#     Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0        93         93  ...      93.0      90.0      93.0      69.0      67.0
# 1        92         92  ...      87.0      83.0      87.0      67.0      69.0
# 2        91         91  ...      89.0      81.0      89.0      66.0      62.0
# 3        91         95  ...      92.0      84.0      92.0      70.0      66.0
# 4        91         93  ...      38.0      41.0      38.0      35.0      39.0
# ..      ...        ...  ...       ...       ...       ...       ...       ...
# 64       86         87  ...      86.0      86.0      86.0      87.0      84.0
# 65       86         89  ...      71.0      77.0      71.0      80.0      85.0
# 66       86         87  ...      87.0      78.0      87.0      63.0      58.0
# 67       86         86  ...      86.0      84.0      86.0      76.0      73.0
# 68       86         88  ...      80.0      84.0      80.0      85.0      87.0
#
#    RWBRating  LBRating  CBRating  RBRating GKRating
# 0       69.0      64.0      53.0      64.0     22.0
# 1       67.0      64.0      63.0      64.0     22.0
# 2       66.0      63.0      56.0      63.0     23.0
# 3       70.0      66.0      57.0      66.0     21.0
# 4       35.0      35.0      36.0      35.0     92.0
# ..       ...       ...       ...       ...      ...
# 64      87.0      86.0      81.0      86.0     22.0
# 65      80.0      82.0      88.0      82.0     21.0
# 66      63.0      59.0      48.0      59.0     16.0
# 67      76.0      71.0      62.0      71.0     20.0
# 68      85.0      85.0      87.0      85.0     21.0
#
# [69 rows x 88 columns]

# %%
top_players[['Name','Overall','Potential','Growth','Nationality']].sort_values(by='Overall',ascending=False)[:10]
# Out:
#                 Name  Overall  Potential  Growth Nationality
# 0           L. Messi       93         93       0   Argentina
# 1     R. Lewandowski       92         92       0      Poland
# 2  Cristiano Ronaldo       91         91       0    Portugal
# 3          K. Mbappé       91         95       4      France
# 4           J. Oblak       91         93       2    Slovenia
# 5       K. De Bruyne       91         91       0     Belgium
# 6          Neymar Jr       91         91       0      Brazil
# 7           N. Kanté       90         90       0      France
# 8            H. Kane       90         90       0     England
# 9      M. ter Stegen       90         92       2     Germany

# %%
count_nationality=top_players.Nationality.value_counts().sort_values(ascending=False)[:20]

# %%
count_nationality
# Out:
# Spain             9
# France            7
# Germany           7
# Brazil            6
# Portugal          5
# England           5
# Italy             5
# Argentina         4
# Belgium           4
# Slovenia          2
# Senegal           2
# Netherlands       2
# Poland            2
# Korea Republic    1
# Egypt             1
# Uruguay           1
# Norway            1
# Costa Rica        1
# Croatia           1
# Scotland          1
# Name: Nationality, dtype: int64

# %% [markdown]
#  Bar graph of countries with most tallented players:-

# %%
px.bar(top_players,
       x=count_nationality.index,y=count_nationality.values,
       color=count_nationality,
       labels={'x': 'Country', 'y':'No. of Players'},
       title="Tallents in countries"
      )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="464c67bb-0e6e-40cb-8ff7-dfc4a604cf36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("464c67bb-0e6e-40cb-8ff7-dfc4a604cf36")) {                    Plotly.newPlot(                        "464c67bb-0e6e-40cb-8ff7-dfc4a604cf36",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>No. of Players=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[9,7,7,6,5,5,5,4,4,2,2,2,2,1,1,1,1,1,1,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Spain","France","Germany","Brazil","Portugal","England","Italy","Argentina","Belgium","Slovenia","Senegal","Netherlands","Poland","Korea Republic","Egypt","Uruguay","Norway","Costa Rica","Croatia","Scotland"],"xaxis":"x","y":[9,7,7,6,5,5,5,4,4,2,2,2,2,1,1,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outl ...

# %%
count_clubs=top_players['Club'].value_counts().sort_values(ascending=False)

# %%
count_clubs
# Out:
# Paris Saint-Germain    9
# Manchester City        9
# Liverpool              8
# FC Bayern München      6
# Manchester United      5
# FC Barcelona           5
# Real Madrid CF         5
# Tottenham Hotspur      3
# Juventus               3
# Atlético de Madrid     3
# Chelsea                2
# Borussia Dortmund      2
# Napoli                 2
# Inter                  2
# Villarreal CF          2
# Lazio                  1
# VfL Wolfsburg          1
# Leicester City         1
# Name: Club, dtype: int64

# %% [markdown]
# Bar graph of clubs with most tallented players:-

# %%
px.bar(top_players,
       x=count_clubs.index,y=count_clubs.values,
       color=count_clubs,
       labels={'x': 'Clubs', 'y':'No. of Players'},
       title="Tallents in clubs"
      )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9db4748a-3e16-435a-9544-38f039bb5e40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9db4748a-3e16-435a-9544-38f039bb5e40")) {                    Plotly.newPlot(                        "9db4748a-3e16-435a-9544-38f039bb5e40",                        [{"alignmentgroup":"True","hovertemplate":"Clubs=%{x}<br>No. of Players=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[9,9,8,6,5,5,5,3,3,3,2,2,2,2,2,1,1,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Paris Saint-Germain","Manchester City","Liverpool","FC Bayern M\u00fcnchen","Manchester United","FC Barcelona","Real Madrid CF","Tottenham Hotspur","Juventus","Atl\u00e9tico de Madrid","Chelsea","Borussia Dortmund","Napoli","Inter","Villarreal CF","Lazio","VfL Wolfsburg","Leicester City"],"xaxis":"x","y":[9,9,8,6,5,5,5,3,3,3,2,2,2,2,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
nationality_player_counts=df['Nationality'].value_counts(ascending=False)

# %%
ind=df['Nationality'].value_counts(ascending=False).index
val=df['Nationality'].value_counts(ascending=False).values

# %%
dict = {'country': ind, 'no_of_players': val}  
nationality_df= pd.DataFrame(dict)

# %%
nationality_df
# Out:
#                       country  no_of_players
# 0                      Brazil            706
# 1                       Spain            674
# 2                   Argentina            571
# 3                      France            479
# 4                     Germany            451
# ..                        ...            ...
# 129                      Chad              1
# 130                  Tanzania              1
# 131        Dominican Republic              1
# 132  Central African Republic              1
# 133                   Eritrea              1
#
# [134 rows x 2 columns]

# %%
nationality_df.columns
# Out:
# Index(['country', 'no_of_players'], dtype='object')

# %% [markdown]
# Number of players per country:-

# %%
px.scatter_geo(nationality_df,
               locations='country',
               size='no_of_players',
               color='country',
               locationmode='country names',
               title="Players per country:-"
              )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7928fa3e-3842-4e05-ba14-0a84aa7b0373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7928fa3e-3842-4e05-ba14-0a84aa7b0373")) {                    Plotly.newPlot(                        "7928fa3e-3842-4e05-ba14-0a84aa7b0373",                        [{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Brazil","locationmode":"country names","locations":["Brazil"],"marker":{"color":"#636efa","size":[706],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Brazil","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Spain","locationmode":"country names","locations":["Spain"],"marker":{"color":"#EF553B","size":[674],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Spain","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Argentina","locationmode":"country names","locations":["Argentina"],"marker":{"color":"#00cc96","size":[571],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Argentina","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"France","locationmode":"country names","locations":["France"],"marker":{"color":"#ab63fa","size":[479],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"France","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Germany","locationmode":"country names","locations":["Germany"],"marker":{"color":"#FFA15A","size":[451],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Germany","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"England","locationmode":"country names","locations":["England"],"marker":{"color":"#19d3f3","size":[449],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"England","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Portugal","locationmode":"country names","locations":["Portugal"],"marker":{"color":"#FF6692","size":[237],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Portugal","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Italy","locationmode":"country names","locations":["Italy"],"marker":{"color":"#B6E880","size":[234],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Italy","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Netherlands","locationmode":"country names","locations":["Netherlands"],"marker":{"color":"#FF97FF","size":[205],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Netherlands","showlegend":true,"type":"scattergeo"},{"geo":"geo","hovertemplate":"country=%{location}<br>no_of_players=%{marker.size}<extra></extra>","legendgroup":"Colombia","locationmode":"country names","locations":["Colombia"],"marker":{"color":"#FECB52","size":[170],"sizemode":"area","sizeref":1.765,"symbol":"circle"},"mode":"markers","name":"Colombia","showlegend":true,"type":"scattergeo"},{"geo": ...

# %%
df1=top_players[['Name','PaceTotal','ShootingTotal','PassingTotal','DribblingTotal','DefendingTotal','PhysicalityTotal']][:3]

# %%
df1
# Out:
#                 Name  PaceTotal  ShootingTotal  PassingTotal  DribblingTotal  \
# 0           L. Messi         85             92            91              95
# 1     R. Lewandowski         78             92            79              85
# 2  Cristiano Ronaldo         87             94            80              87
#
#    DefendingTotal  PhysicalityTotal
# 0              34                65
# 1              44                82
# 2              34                75

# %% [markdown]
# Radar chart of top 3 players:-

# %%
pi=3.14
categories=list(df1)[1:]
N = len(categories)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
ax = plt.subplot(111, polar=True)
 
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
plt.xticks(angles[:-1], categories)
ax.set_rlabel_position(0)
plt.yticks([20,40,60,80,100], ["20","40","60","80","100"], color="grey", size=7)
plt.ylim(0,100)
  
# L. Messi
values=df1.loc[0].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="L Messi")
ax.fill(angles, values, 'b', alpha=0.1)
 
#R. Lewandowski
values=df1.loc[1].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="R. Lewandowski")
ax.fill(angles, values, 'r', alpha=0.1)

#Christiano Ronaldo
values=df1.loc[2].drop('Name').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Christiano Ronaldo")
ax.fill(angles, values, 'g', alpha=0.1)

plt.title("Top 3 players comparison")
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %% [markdown]
# Bar graph for top 20 heighest paid players:-

# %%
heighest_paid=df[["Name","ValueEUR"]].sort_values(by="ValueEUR",ascending=False)[:20]

# %%
px.bar(heighest_paid,
       x=heighest_paid["Name"],y=heighest_paid["ValueEUR"],
       color=heighest_paid["ValueEUR"],
       labels={'x': 'Players', 'y':'Value(in EUR)'},
       title="Heighest paid players:"
      )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="79280937-cee1-4d49-b914-dda05e192ac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79280937-cee1-4d49-b914-dda05e192ac1")) {                    Plotly.newPlot(                        "79280937-cee1-4d49-b914-dda05e192ac1",                        [{"alignmentgroup":"True","hovertemplate":"Name=%{x}<br>ValueEUR=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[194000000,137500000,129500000,129000000,125500000,119500000,119500000,119500000,116500000,114000000,112000000,108000000,107500000,107500000,104000000,102500000,101000000,101000000,100000000,99000000],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["K. Mbapp\u00e9","E. Haaland","H. Kane","Neymar Jr","K. De Bruyne","F. de Jong","R. Lewandowski","G. Donnarumma","J. Sancho","T. Alexander-Arnold","J. Oblak","J. Kimmich","Bruno Fernandes","R. Sterling","H. Son","R\u00faben Dias","S. Man\u00e9","M. Salah","N. Kant\u00e9","M. ter Stegen"],"xaxis":"x","y":[194000000,137500000,129500000,129000000,125500000,119500000,119500000,119500000,116500000,114000000,112000000,108000000,107500000,107500000,104000000,102500000,101000000,101000000,100000000,99000000],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outline ...
